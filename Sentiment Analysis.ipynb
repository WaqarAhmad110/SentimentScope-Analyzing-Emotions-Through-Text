# %% [raw]
# Install Tensorflow and keras library
# Open cmd and write "pip install tensorflow"
# Check the version and confirm installation of tensorflow

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.18.0

# %% [raw]
# Check the keras library confirmation and version
# Keras is a high-level, open-source neural network library written in Python. It provides a simple and consistent API to build and train deep learning models. Keras is designed to be user-friendly, modular, and extensible, making it ideal for beginners and researchers alike.

# %%
import tensorflow as tf 
print(tf.keras.__version__)
# Out:
# 3.7.0

# %% [raw]
#                                                    What is Sentiment Analysis ?
# Sentiment analysis is also called opinion mining. It is very powerful technique to analysis.
#
# Sentiment anaylysis is a NLP technique use to determine the emotions and tone behind a body of text. It classify the text is positive, negative or neutral.
#
# For Example:
# Review 1: This Movie is too good --> Positive
# Review 2: This movie is waste of time --> Negative
# Review 3: i spend my extra time on it --> Neutral

# %% [raw]
#                                                   Types of Sentiment Analysis
#
# 1- Binary Sentiment Analysis:-
#
# It's classify the text into two categories POSITIVE & NEGATIVE
# example: "This product is very usefull" -->Positive
#          "This is product is terrible" --> Negative
#
# 2- Multiclass Sentiment Analysis:-
#
# It's classify the text into multiple categories like VERY POSITIVE, POSTIVE, NEUTRAL, NEGATIVE, VERY NEGATIVE
# example: "This is so amazing movie. highly recommended " --> Very Positive
#          "This is very informative movie " --> Positive
#          "That product is delivered today" --> Neutral
#          "The decision is terrible for the people" --> Negative
#          "The is very bad and waste of money product. avoid this" --> Very Negative
#
# 3- Emotion Detection:-
#
# Identify the specific emotion like HAPPY, SAD,ANGRY or FEAR
# example: "I am very comfortable with this job" --> Happy
#          "This movie is so emotional" --> sad
#          "I hate this product"--> Angry
#          "I don't like horror movies" --> Fear
#
# 4- Aspect-Based Sentiment Analysis:-
#
# Detects sentiment about specific aspects of a product or service.
# Example: "The phone's battery life is excellent, but the camera is subpar."
#             Battery → Positive
#             Camera → Negative

# %% [raw]
#                                                  Real World Examples of Sentiment Analysis
# Social Media Analysis :-
# Twitter: Analysis the tweets and determine the public opinion about political event
# example "I can’t believe this decision. Terrible for the people!" --> Negative
#
# E commerce:-
# Amazon: Analysis the customer reviews about product
#
# Customer Support and surveys
# Movie Reviews:-
# IMDb: Analysis the movie reviews. Peoples like or dislike it

# %% [raw]
#                                                How does work sentiment analysis
# 1- Data Collection:- (-Reviews(aliexpress, Alibaba, Amazon or IMDb)-)
#                      (-Surveys and Customer feedback-)
#                      (-Social Media(Twitter, Facebook or instagram)-)
#
# 2- Text Processing:-(Text should be clean and remove irrelevent data or text. and it should be in good format. These are few step below to refine text or                     data )
#                    (1- LOWERCASE Convert text to lowercase e.g "Product"=> "product")
#                    (2- TOKENIZATION Break text into words or phrases "I like this Product"=> "'i','like','this','product'")
#                    (3- STOPWORD REMOVAL remove word like 'is','are','the','that' and add little meaning)
#                    (4- STEMMING/ LEMMATIZATION reduce words to their base form like 'running', 'runs', 'ran' ---> run)
#
# 3- Feature Extraction:-(Convert text into numerical format for machine learning)
#                        BoW: Bag of word
#                        TF-IDF: Term Frequency-Inverse Document Frequency
#                        Word Embeddings
#
# 4- Model Trainng:-  Use Machine Learning Models like Naive Bayes, Support Vector Machines (SVM), or Random Forest for small datasets
#                     Use Deep Learning Models like Recurrent Neural Networks (RNN), Long Short-Term Memory (LSTM), or Transformer-based models like BERT                      for large datasets.
#
# 5- Model Evaluation:- Evaluate performance using metrics like:
#
#                       Accuracy: Percentage of correctly classified instances.
#                       Precision and Recall: Quality of predictions.
#                     F1-Score: Harmonic mean of precision and recall.

# %%
#Importing Libraries 
import tensorflow as tf                                        # this is main library for building and training deep lerining modules 
from tensorflow.keras.datasets import imdb                     # imdb is built-in dateset in tensorflow consists of 50k reviews (+,-)
from tensorflow.keras.preprocessing.sequence import pad_sequences  # pad_sequences confirm all reviews will be in sort form by padding 
from tensorflow.keras.models import Sequential                 # Sequential class building models layer by layer 
from tensorflow.keras.layers import Embedding, LSTM, Dense     

vocab_size = 10000                                               #Limit the dataset only choose top 10,000 from datasets                                
max_len = 100                                                  #Maximum size of review will be 100
(x_train, y_train),(x_test, y_test) = imdb.load_data(num_words = vocab_size) #load datasets from imdb and auto tokenization words to indexing 

x_train = pad_sequences(x_train, maxlen=max_len)
x_test = pad_sequences(x_test, maxlen=max_len)
model = Sequential([
    Embedding(input_dim=vocab_size, output_dim=32, input_length=max_len),  # Word embedding
    LSTM(64),                                                             # LSTM layer for sequence processing
    Dense(1, activation='sigmoid')                                        # Output layer (binary classification)
])
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])
history = model.fit(x_train, y_train, epochs=5, batch_size=64, validation_split=0.2)
loss, accuracy = model.evaluate(x_test, y_test)
print(f"Test Accuracy: {accuracy * 100:.2f}%")
import matplotlib.pyplot as plt

# Plot accuracy
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.legend()
plt.title('Accuracy Over Epochs')
plt.show()

# Plot loss
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend()
plt.title('Loss Over Epochs')
plt.show()
# Out:
# Epoch 1/5
# C:\Users\Administrator\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 17s 46ms/step - accuracy: 0.6798 - loss: 0.5792 - val_accuracy: 0.8408 - val_loss: 0.3608
# Epoch 2/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 14s 45ms/step - accuracy: 0.8950 - loss: 0.2658 - val_accuracy: 0.8470 - val_loss: 0.3473
# Epoch 3/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 22s 48ms/step - accuracy: 0.9260 - loss: 0.2009 - val_accuracy: 0.8466 - val_loss: 0.3744
# Epoch 4/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 16s 52ms/step - accuracy: 0.9489 - loss: 0.1460 - val_accuracy: 0.8370 - val_loss: 0.4586
# Epoch 5/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 15s 47ms/step - accuracy: 0.9662 - loss: 0.1015 - val_accuracy: 0.8288 - val_loss: 0.5287
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 10s 13ms/step - accuracy: 0.8291 - loss: 0.5433
# Test Accuracy: 82.83%

# %%
import matplotlib
print(matplotlib.__version__)
# Out:
# 3.9.3
